# %% [markdown]
# # Exercice 2
# ## Boudelal Abderahmane And Nahoui Seif
# reponse 1:
# import libraries and dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets,linear_model,model_selection

# %%
x,y = datasets.load_diabetes(return_X_y=True)

# %% [markdown]
# ## Reponse 2:
# x.shape / print the data shape
# x[0]: First element

# %%
print(x.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
x[0]
# Out:
# array([ 0.03807591,  0.05068012,  0.06169621,  0.02187239, -0.0442235 ,
#        -0.03482076, -0.04340085, -0.00259226,  0.01990749, -0.01764613])

# %% [markdown]
# this data base containes 442 samples and 10 features

# %% [markdown]
# ## Reponse 3 :

# %%
x = x[:, 2]  # Access the third column
x = x[:, np.newaxis]

# %%
x.shape
# Out:
# (442, 1)

# %% [markdown]
# ## Reponse 4:
# split the data into train and test

# %% [markdown]
# x_train , x_test , y_train , y_test = model_selection.train_test_split(x,y,test_size=0.25,random_state=5)

# %% [markdown]
# ## Reponse5:
# create a linear regression Model

# %%
x_train , x_test , y_train , y_test = model_selection.train_test_split(x,y,test_size=0.25,random_state=5)

# %%
model = linear_model.LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Reponses 6:
# predict the data

# %%
predicted_y = model.predict(x_test)

# %% [markdown]
# ## Reponses 7:
# Accuracy score

# %%
print(f"predicted y2 = {predicted_y[1]}")
print(f"actual y2 = {y_test[1]}")
# Out:
# predicted y2 = 222.33408257247947
# actual y2 = 332.0

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test, predicted_y)
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.33275881449507416

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,predicted_y, color= 'red')
plt.show()

# %% [markdown]
# ## Reponse 9 :
# repeat stpes from 2 to 7 obtain  most predictive feature is feature 9 with an R-squared score of 0.4215743297548834

# %%
# Load the diabetes dataset
X, y = datasets.load_diabetes(return_X_y=True)

# Iterate through each feature (except the first two)
best_feature = None
best_accuracy = 0
for i in range(2, X.shape[1]):
    X_feature = X[:, i].reshape(-1, 1)  # Extract the current feature
    X_train, X_test, y_train, y_test = model_selection.train_test_split(X_feature, y, test_size=0.25, random_state=42)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = r2_score(y_test, y_pred)
    print(f"Accuracy for feature {i+1}: {accuracy}")
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_feature = i+1

print(f"The most predictive feature is feature {best_feature} with an R-squared score of {best_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e1cdbeba8e29> in <cell line: 7>()
#       8     X_feature = X[:, i].reshape(-1, 1)  # Extract the current feature
#       9     X_train, X_test, y_train, y_test = model_selection.train_test_split(X_feature, y, test_size=0.25, random_state=42)
# ---> 10     model = LinearRegression()
#      11     model.fit(X_train, y_train)
#      12     y_pred = model.predict(X_test)
#
# NameError: name 'LinearRegression' is not defined
